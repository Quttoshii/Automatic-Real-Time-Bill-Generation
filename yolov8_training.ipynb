# %%
# pip install ultralytics==8.0.196

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196  Python-3.11.8 torch-2.3.0+cpu CPU (Intel Core(TM) i3-8130U 2.20GHz)
# Setup complete  (4 CPUs, 11.9 GB RAM, 34.8/931.4 GB disk)

# %%
from ultralytics import YOLO

# Load a model
# model = YOLO('yolov8n.yaml')  # build a new model from scratch
model = YOLO('yolov8n.pt')  # loading a pretrained model
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:02<00:00, 2.98MB/s]

# %%
# Training the model
results = model.train(data='AugmentedDatasetv8\data.yaml', epochs=100,batch=32)  # train the model
# Out:
# New https://pypi.org/project/ultralytics/8.2.11 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196  Python-3.11.8 torch-2.3.0+cpu CPU (Intel Core(TM) i3-8130U 2.20GHz)
# ...

# %%
# Testing the model
results = model('test.jpeg', save=True)  # predict on an image
# Out:
# image 1/1 d:\FAST\Semester 6\Artificial Intelligence\Project\test.jpeg: 640x640 1 bottle, 1 lunchbox, 1 register, 490.7ms
# Speed: 24.8ms preprocess, 490.7ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict4
